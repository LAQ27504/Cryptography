# %%
k_pr = int(input("k pr: "))
k_pub = input("k public: ").split(" ")
p, a , b = k_pub
p = int(p)
a = int(a)
b = int(b)
x_b = int(input("x: "))
k_e = int(input("k e: "))

# %%
r = pow(a, k_e, p)
print(r)

s = ((x_b - k_pr * r) * pow(k_e, -1, (p - 1))) % (p - 1)
print(s)
b = pow (a,k_pr ,p)
print(b)
t = (pow(b,r,p) * pow(r, s,p)) % p

valid = pow(a, x_b, p)
print(t)
print(valid)
print(t == valid)
# Out:
# 227
# 71
# 435
# 194
# 194
# True

# %%
x1, r1, s1 = input().split(' ')
x1 = int(x1)
r1 = int(r1)
s1 = int(s1)
t = (pow(b,r1) * pow(r1, s1)) % p
print(t == pow(a,x1, p))
# Out:
# False

# %%
p = 863
al = 2
a = 2023
b = 2024
a %= p
b %= p

# %%
k_a = pow(al, a, p)
k_b = pow(al, b, p)
print(k_a)
print(k_b)
print(pow(k_a, b,p))
print(pow(k_b, a,p))
# Out:
# 373
# 746
# 673
# 673
